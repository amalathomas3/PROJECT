# %% [markdown]
# # Prediction of Bitcoin Prices: Comparison of LSTM and GRU

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout,GRU,LSTM
from keras import optimizers 
import tensorflow as tf
import sklearn.metrics as sm
from keras.preprocessing.sequence import TimeseriesGenerator

seed = 1234
np.random.seed(seed)
plt.style.use('ggplot')

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # Importing the dataset and describing

# %%
path_to_data = "../dataset/BTC-Hourly.csv" 
df = pd.read_csv(path_to_data,index_col='date', parse_dates=['date']) 
df.describe()
# Out:
#                unix          open          high           low         close  \
# count  3.325900e+04  33259.000000  33259.000000  33259.000000  33259.000000
# mean   1.586228e+09  20119.546772  20232.957473  19997.069777  20120.684800
# std    3.456429e+07  18537.219607  18646.950933  18418.320297  18537.695044
# min    1.526364e+09   3139.760000   3158.340000   3122.280000   3139.760000
# 25%    1.556296e+09   7022.865000   7055.835000   6970.570000   7022.865000
# 50%    1.586228e+09   9700.040000   9740.270000   9657.000000   9700.320000
# 75%    1.616161e+09  36415.305000  36735.380000  36104.235000  36423.040000
# max    1.646093e+09  68635.050000  69000.000000  68447.000000  68627.010000
#
#          Volume BTC    Volume USD
# count  3.325900e+04  3.325900e+04
# mean   1.612380e+06  2.965701e+06
# std    3.102328e+06  7.329787e+06
# min    0.000000e+00  0.000000e+00
# 25%    1.903241e+02  1.682800e+02
# 50%    6.093271e+05  5.248300e+02
# 75%    1.929240e+06  3.120014e+06
# max    6.857061e+07  2.582324e+08

# %% [markdown]
# # Checking the dataset for NULL values

# %%
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# # Plotting the dataset

# %%
plt.bar(df['open'],df['close'])
plt.xlabel('open')
plt.ylabel('close')
plt.show()

# %%
plt.bar(df['high'],df['close'])
plt.xlabel('high')
plt.ylabel('close')
plt.show()

# %%
plt.bar(df['low'],df['close'])
plt.xlabel('low')
plt.ylabel('close')
plt.show()

# %% [markdown]
# # Feature Selection and plotting the dataset

# %%
dataset = pd.DataFrame(df['close'])
print(' Count row of data: ',len(dataset))
#to order ascending
dataset=dataset.iloc[::-1]
fig = plt.figure(figsize=(14, 6))
plt.plot(dataset,color="blue")
plt.xlabel('Date')
plt.ylabel('Bitcoin Price (USD)')
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m"))
plt.title('Bitcoin Price')
plt.show()
# Out:
#  Count row of data:  33259

# %% [markdown]
# # Preprocessing Data

# %% [markdown]
# ## Normalization Using Min-Max

# %%
dataset_norm = dataset.copy()
dataset[['close']]
scaler = MinMaxScaler()
dataset_norm['close'] = scaler.fit_transform(dataset[['close']])
dataset_norm
# Out:
#                         close
# date
# 2018-05-15 06:00:00  0.085532
# 2018-05-15 07:00:00  0.085501
# 2018-05-15 08:00:00  0.085341
# 2018-05-15 09:00:00  0.085033
# 2018-05-15 10:00:00  0.086370
# ...                       ...
# 2022-02-28 20:00:00  0.592103
# 2022-02-28 21:00:00  0.588203
# 2022-02-28 22:00:00  0.607257
# 2022-02-28 23:00:00  0.611405
# 2022-03-01 00:00:00  0.613440
#
# [33259 rows x 1 columns]

# %% [markdown]
# ## Graph Data Normalized

# %%
fig = plt.figure(figsize=(10, 4))
plt.plot(dataset_norm)
plt.xlabel('Date')
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m"))
plt.title('Data Normalized')
plt.show()

# %% [markdown]
# ##

# %% [markdown]
# # MODEL CREATION

# %% [markdown]
# ## DATA PARTITION

# %%
# Partition data into data train, val & test
totaldata = dataset.values
totaldatatrain = int(len(totaldata)*0.75)
totaldataval = int(len(totaldata)*0.1)
totaldatatest = int(len(totaldata)*0.15)

# Store data into each partition
training_set = dataset_norm[0:totaldatatrain]
val_set=dataset_norm[totaldatatrain:totaldatatrain+totaldataval]
test_set = dataset_norm[totaldatatrain+totaldataval:]

# %% [markdown]
# ## TRAINING DATA GRAPH

# %%
# graph of data training
fig = plt.figure(figsize=(10, 4))
plt.plot(training_set)
plt.xlabel('Date')
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m"))
plt.title('Data Training')
plt.show()
training_set
# Out:
#                         close
# date
# 2018-05-15 06:00:00  0.085532
# 2018-05-15 07:00:00  0.085501
# 2018-05-15 08:00:00  0.085341
# 2018-05-15 09:00:00  0.085033
# 2018-05-15 10:00:00  0.086370
# ...                       ...
# 2021-03-19 09:00:00  0.842100
# 2021-03-19 10:00:00  0.847065
# 2021-03-19 11:00:00  0.850596
# 2021-03-19 12:00:00  0.850722
# 2021-03-19 13:00:00  0.841615
#
# [24944 rows x 1 columns]

# %% [markdown]
# ## DATA VALIDATION GRAPH

# %%
# graph of data validation
fig = plt.figure(figsize=(10, 4))
plt.plot(val_set)
plt.xlabel('Date')
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m"))
plt.title('Data Validation')
val_set
# Out:
#                         close
# date
# 2021-03-19 14:00:00  0.848515
# 2021-03-19 15:00:00  0.853007
# 2021-03-19 16:00:00  0.851354
# 2021-03-19 17:00:00  0.851709
# 2021-03-19 18:00:00  0.850357
# ...                       ...
# 2021-08-04 22:00:00  0.558810
# 2021-08-04 23:00:00  0.558908
# 2021-08-05 00:00:00  0.556097
# 2021-08-05 01:00:00  0.555316
# 2021-08-05 02:00:00  0.553487
#
# [3325 rows x 1 columns]

# %% [markdown]
# ## TEST DATA GRAPH

# %%
# graph of data test
fig = plt.figure(figsize=(10, 4))
plt.plot(test_set)
plt.xlabel('Date')
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m"))
plt.title('Data Test')
plt.show()
test_set
# Out:
#                         close
# date
# 2021-08-05 03:00:00  0.554312
# 2021-08-05 04:00:00  0.553270
# 2021-08-05 05:00:00  0.552882
# 2021-08-05 06:00:00  0.548914
# 2021-08-05 07:00:00  0.545520
# ...                       ...
# 2022-02-28 20:00:00  0.592103
# 2022-02-28 21:00:00  0.588203
# 2022-02-28 22:00:00  0.607257
# 2022-02-28 23:00:00  0.611405
# 2022-03-01 00:00:00  0.613440
#
# [4990 rows x 1 columns]

# %% [markdown]
# ## CREATING GENERATORS

# %%
look_back = 15

train_generator = TimeseriesGenerator(training_set, training_set, length=look_back, batch_size=512)     
test_generator = TimeseriesGenerator(test_set, test_set, length=look_back, batch_size=1)
validation_generator = TimeseriesGenerator(val_set, val_set, length=look_back, batch_size=1)

# %% [markdown]
# # MODEL LSTM

# %%
# Hyperparameters
learning_rate = 0.0001
hidden_unit=30
batch_size=512
epoch = 100
OPTIMIZER = tf.keras.optimizers.Adam(learning_rate=learning_rate)
METRICS = [tf.keras.metrics.Accuracy()]

# Architecture LSTM
regressorLSTM = Sequential()

# First LSTM layer with dropout
regressorLSTM.add(LSTM(units=hidden_unit, return_sequences=True, input_shape=(look_back,1)))
regressorLSTM.add(Dropout(0.2))
# Second LSTM layer with dropout
regressorLSTM.add(LSTM(units=hidden_unit, return_sequences=True))
regressorLSTM.add(Dropout(0.2))
# Third LSTM layer with dropout
regressorLSTM.add(LSTM(units=hidden_unit, return_sequences=True))
regressorLSTM.add(Dropout(0.2))
# Fourth LSTM layer with dropout
regressorLSTM.add(LSTM(units=hidden_unit))
regressorLSTM.add(Dropout(0.2))

# Output layer
regressorLSTM.add(Dense(units=1))

# Compiling the LSTM
regressorLSTM.compile(optimizer=OPTIMIZER,loss=tf.losses.mean_squared_error)

regressorLSTM.summary()

# Fitting  data training dan data validation
pred = regressorLSTM.fit(train_generator, validation_data=validation_generator, epochs=epoch,verbose=1)

regressorLSTM.save("LSTM.h5")
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 15, 30)            3840
#
#  dropout_4 (Dropout)         (None, 15, 30)            0
#
#  lstm_5 (LSTM)               (None, 15, 30)            7320
#
#  dropout_5 (Dropout)         (None, 15, 30)            0
#
#  lstm_6 (LSTM)               (None, 15, 30)            7320
#
#  dropout_6 (Dropout)         (None, 15, 30)            0
#
#  lstm_7 (LSTM)               (None, 30)                7320
#
#  dropout_7 (Dropout)         (None, 30)                0
#
#  dense_1 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 25,831
# Trainable params: 25,831
# Non-trainable params: 0
# _________________________________________________________________
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2596\1771689883.py in <module>
#      32
#      33 # Fitting  data training dan data validation
# ---> 34 pred = regressorLSTM.fit(train_generator, validation_data=validation_generator, epochs=epoch,verbose=1)
#      35
#      36 regressorLSTM.save("LSTM.h5")
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 15

# %% [markdown]
# ## TRAINING LOSS AND VALIDATION LOSS GRAPH

# %%
# Graph model loss (train loss & val loss)
fig = plt.figure(figsize=(10, 4))
plt.plot(pred.history['loss'], label='train loss')
plt.plot(pred.history['val_loss'], label='val loss')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ## Training Loss & Validation Loss Table

# %%
# Tabel value of training loss & validation loss
learningrate_parameter = learning_rate
train_loss=pred.history['loss'][-1]
validation_loss=pred.history['val_loss'][-1]
learningrate_parameter=pd.DataFrame(data=[[learningrate_parameter, train_loss, validation_loss]],
                                    columns=['Learning Rate', 'Training Loss', 'Validation Loss'])
learningrate_parameter.set_index('Learning Rate')
# Out:
#                Training Loss  Validation Loss
# Learning Rate
# 0.0001              0.000768         0.000697

# %% [markdown]
# ## Implementation Model into Data Test

# %%
# Implementation model into data test
y_pred_test = regressorLSTM.predict_generator(test_generator)

# Invert normalization min-max
y_pred_invert_norm = scaler.inverse_transform(y_pred_test)
# Out:
# x_test:  [[[0.55431248]]
#
#  [[0.55326953]]
#
#  [[0.55288197]]
#
#  ...
#
#  [[0.58820259]]
#
#  [[0.60725653]]
#
#  [[0.61140482]]]

# %% [markdown]
# ## Comparison Data Test with Prediction Results

# %%
# Comparison data test with data prediction
datacompareLSTM = pd.DataFrame()
datatest=np.array(dataset['close'][totaldatatrain+totaldataval+lag:])
datapred= y_pred_invert_norm

datacompareLSTM['Data Test'] = datatest
datacompareLSTM['Prediction Results'] = datapred
datacompareLSTM
# Out:
#       Data Test  Prediction Results
# 0      39371.86        39360.738281
# 1      39346.48        39296.851562
# 2      39086.66        39273.105469
# 3      38864.34        39029.734375
# 4      38473.23        38821.089844
# ...         ...                 ...
# 4984   41914.97        41144.273438
# 4985   41659.53        41651.503906
# 4986   42907.32        41417.277344
# 4987   43178.98        42556.449219
# 4988   43312.27        42802.777344
#
# [4989 rows x 2 columns]

# %% [markdown]
# ## Prediction Results Evaluation

# %%
# Calculatre value of Root Mean Square Error 
def rmse(datatest, datapred):
    return np.round(np.sqrt(np.mean((datapred - datatest) ** 2)), 4)
print('Result Root Mean Square Error LSTM :',rmse(datatest, datapred))

def mape(datatest, datapred): 
    return np.round(np.mean(np.abs((datatest - datapred) / datatest) * 100), 4)
    
print('Result Mean Absolute Percentage Error LSTM : ', mape(datatest, datapred), '%')

print("Model Accuracy:",100-mape(datatest, datapred), '%')
# Out:
# Result Root Mean Square Error LSTM : 10473.7572
# Result Mean Absolute Percentage Error LSTM :  16.9124 %
# Model Accuracy: 83.0876 %

# %%
# Create graph data test and prediction result
plt.figure(num=None, figsize=(10, 4), dpi=80,facecolor='w', edgecolor='k')
plt.title('Graph Comparison Data Actual and Data Prediction LSTM')
plt.plot(datacompareLSTM['Data Test'], color='red',label='Data Test')
plt.plot(datacompareLSTM['Prediction Results'], color='blue',label='Prediction Results')
plt.xlabel('Day')
plt.ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# # MODEL GRU

# %%
# Hyperparameters
learning_rate = 0.0001
hidden_unit=30
batch_size=512
epoch = 100
OPTIMIZER = tf.keras.optimizers.Adam(learning_rate=learning_rate)

# Architecture Gated Recurrent Unit
regressorGRU = Sequential()

# First GRU layer with dropout
regressorGRU.add(GRU(units=hidden_unit, return_sequences=True, input_shape=(x_train.shape[1],1)))
regressorGRU.add(Dropout(0.2))
# Second GRU layer with dropout
regressorGRU.add(GRU(units=hidden_unit, return_sequences=True))
regressorGRU.add(Dropout(0.2))
# Third GRU layer with dropout
regressorGRU.add(GRU(units=hidden_unit, return_sequences=True))
regressorGRU.add(Dropout(0.2))
# Fourth GRU layer with dropout
regressorGRU.add(GRU(units=hidden_unit))
regressorGRU.add(Dropout(0.2))

# Output layer 
regressorGRU.add(Dense(units=1))

# Compiling the GRU
regressorGRU.compile(optimizer=OPTIMIZER,loss='mean_squared_error')

# Fitting ke data training dan data validation
pred = regressorGRU.fit(x_train, y_train, validation_data=(x_val,y_val), batch_size=batch_size, epochs=epoch,verbose=1)

regressorGRU.save("GRU.h5")
# Out:
# Epoch 1/100
# 49/49 [==============================] - 7s 33ms/step - loss: 0.0334 - val_loss: 0.3562
# Epoch 2/100
# 49/49 [==============================] - 1s 10ms/step - loss: 0.0256 - val_loss: 0.2908
# Epoch 3/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0216 - val_loss: 0.2408
# Epoch 4/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0195 - val_loss: 0.2106
# Epoch 5/100
# 49/49 [==============================] - 1s 12ms/step - loss: 0.0169 - val_loss: 0.1690
# Epoch 6/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0125 - val_loss: 0.1085
# Epoch 7/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0070 - val_loss: 0.0401
# Epoch 8/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0027 - val_loss: 0.0057
# Epoch 9/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0015 - val_loss: 8.1269e-04
# Epoch 10/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0014 - val_loss: 8.1621e-04
# Epoch 11/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0013 - val_loss: 4.3723e-04
# Epoch 12/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0013 - val_loss: 3.5028e-04
# Epoch 13/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0013 - val_loss: 4.2098e-04
# Epoch 14/100
# 49/49 [==============================] - 1s 10ms/step - loss: 0.0013 - val_loss: 7.6034e-04
# Epoch 15/100
# 49/49 [==============================] - 1s 13ms/step - loss: 0.0013 - val_loss: 4.4874e-04
# Epoch 16/100
# 49/49 [==============================] - 1s 10ms/step - loss: 0.0012 - val_loss: 3.5241e-04
# Epoch 17/100
# 49/49 [==============================] - 1s 10ms/step - loss: 0.0012 - val_loss: 3.1138e-04
# Epoch 18/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0013 - val_loss: 2.9794e-04
# Epoch 19/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012 - val_loss: 3.8581e-04
# Epoch 20/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0012 - val_loss: 4.0404e-04
# Epoch 21/100
# 49/49 [==============================] - 1s 12ms/step - loss: 0.0011 - val_loss: 2.9137e-04
# Epoch 22/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011 - val_loss: 3.7158e-04
# Epoch 23/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011 - val_loss: 4.9783e-04
# Epoch 24/100
# 49/49 [==============================] - 1s 12ms/step - loss: 0.0012 - val_loss: 4.5317e-04
# Epoch 25/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011 - val_loss: 3.1361e-04
# Epoch 26/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011 - val_loss: 2.4995e-04
# Epoch 27/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011 - val_loss: 4.7112e-04
# Epoch 28/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011 - val_loss: 3.2213e-04
# Epoch 29/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011 - val_loss: 4.7489e-04
# Epoch 30/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011 - val_loss: 6.3906e-04
# Epoch 31/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011 - val_loss: 4.3904e-04
# Epoch 32/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011 - val_loss: 5.8337e-04
# Epoch 33/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0010 - val_loss: 2.8074e-04
# Epoch 34/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0010 - val_loss: 3.9652e-04
# Epoch 35/100
# 49/49 [==============================] - 1s 12ms/step - loss: 0.0011 - val_loss: 2.0581e-04
# Epoch 36/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0010 - val_loss: 4.8970e-04
# Epoch 37/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0011 - val_loss: 2.9349e-04
# Epoch 38/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0010 - val_loss: 5.2528e-04
# Epoch 39/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0010 - val_loss: 4.8078e-04
# Epoch 40/100
# 49/49 [==============================] - 1s 12ms/step - loss: 0.0010 - val_loss: 4.7967e-04
# Epoch 41/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0010 - val_loss: 2.2438e-04
# Epoch 42/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0010 - val_loss: 4.2513e-04
# Epoch 43/100
# 49/49 [==============================] - 1s 11ms/step - loss: 9.8237e-04 - val_loss: 3.0330e-04
# Epoch 44/100
# 49/49 [==============================] - 1s 11ms/step - loss: 9.7954e-04 - val_loss: 7.8951e-04
# Epoch 45/100
# 49/49 [==============================] - 1s 11ms/step - loss: 9.8409e-04 - val_loss: 3.5190e-04
# Epoch 46/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0010 - val_loss: 3.2546e-04
# Epoch 47/100
# 49/49 [==============================] - 1s 11ms/step - loss: 9.5160e-04 - val_loss: 5.5023e-04
# Epoch 48/100
# 49/49 [==============================] - 1s 11ms/step - loss: 9.5901e-04 - val_loss: 5.9941e-04
# Epoch 49/100
# 49/49 [==============================] - 1s 11ms/step - loss: 9.6406e-04 - val_loss: 4.3518e-04
# Epoch 50/100
# 49/49 [==============================] - 1s 11ms/step - loss: 9.6408e-04 - val_loss: 5.2735e-04
# Epoch 51/100
# 49/49 [==============================] - 1s 11ms/step - loss: 9.3368e-04 - val_loss: 4.7482e-04
# Epoch 52/100
# 49/49 [==============================] - 1s 11ms/step - loss: 9.5310e-04 - val_loss: 7.1367e-04
# Epoch 53/100
# 49/49 [==============================] - 1s 11ms/step - loss: 9.3213e-04 - val_loss: 4.3822e-04
# Epoch 54/100
# 49/49 [==============================] - 1s 11ms/step - loss: 9.4774e-04 - val_loss: 4.0403e-04
# Epoch 55/100
# 49/49 [==============================] - 1s 11ms/step - loss: 9.1698e-04 - val_loss: 6.8593e-04
# Epoch 56/100
# 49/49 [==============================] - 1s 11ms/step - loss: 9.3915e-04 - val_loss: 6.7980e-04
# Epoch 57/100
# 49/49 [==============================] - 1s 11ms/step - loss: 8.8238e-04 - val_loss: 4.5899e-04
# Epoch 58/100
# 49/49 [==============================] - 1s 11ms/step - loss: 9.3542e-04 - val_loss: 4.0079e-04
# Epoch 59/100
# 49/49 [==============================] - 1s 11ms/step - loss: 9.3705e-04 - val_loss: 4.2403e-04
# Epoch 60/100
# 49/49 [==============================] - 1s 11ms/step - loss: 8.8224e-04 - val_loss: 9.0388e-04
# Epoch 61/100
# 49/49 [==============================] - 1s 11ms/step - loss: 8.7837e-04 - val_loss: 4.5047e-04
# Epoch 62/100
# 49/49 [==============================] - 1s 11ms/step - loss: 9.2167e-04 - val_loss: 4.2603e-04
# Epoch 63/100
# 49/49 [==============================] - 1s 11ms/step - loss: 9.1754e-04 - val_loss: 4.3913e-04
# Epoch 64/100
# 49/49 [==============================] - 1s 12ms/step - loss: 8.5497e-04 - val_loss: 9.0531e-04
# Epoch 65/100
# 49/49 [==============================] - 1s 10ms/step - loss: 8.9670e-04 - val_loss: 5.6331e-04
# Epoch 66/100
# 49/49 [==============================] - 1s 11ms/step - loss: 8.2859e-04 - val_loss: 6.7005e-04
# Epoch 67/100
# 49/49 [==============================] - 1s 11ms/step - loss: 8.7935e-04 - val_loss: 5.8887e-04
# Epoch 68/100
# 49/49 [==============================] - 1s 11ms/step - loss: 8.6536e-04 - val_loss: 6.2572e-04
# Epoch 69/100
# 49/49 [==============================] - 1s 11ms/step - loss: 8.4635e-04 - val_loss: 5.0679e-04
# Epoch 70/100
# 49/49 [==============================] - 1s 11ms/step - loss: 8.7348e-04 - val_loss: 4.8836e-04
# Epoch 71/100
# 49/49 [==============================] - 1s 11ms/step - loss: 8.7119e-04 - val_loss: 0.0011
# Epoch 72/100
# 49/49 [==============================] - 1s 11ms/step - loss: 8.4160e-04 - val_loss: 5.2225e-04
# Epoch 73/100
# 49/49 [==============================] - 1s 13ms/step - loss: 8.6336e-04 - val_loss: 7.8634e-04
# Epoch 74/100
# 49/49 [==============================] - 1s 12ms/step - loss: 8.2963e-04 - val_loss: 5.2944e-04
# Epoch 75/100
# 49/49 [==============================] - 1s 12ms/step - loss: 7.9847e-04 - val_loss: 3.9661e-04
# Epoch 76/100
# 49/49 [==============================] - 1s 12ms/step - loss: 8.1002e-04 - val_loss: 9.4037e-04
# Epoch 77/100
# 49/49 [==============================] - 1s 14ms/step - loss: 8.2428e-04 - val_loss: 5.9832e-04
# Epoch 78/100
# 49/49 [==============================] - 1s 13ms/step - loss: 8.1040e-04 - val_loss: 6.5164e-04
# Epoch 79/100
# 49/49 [==============================] - 1s 11ms/step - loss: 8.8280e-04 - val_loss: 6.0984e-04
# Epoch 80/100
# 49/49 [==============================] - 1s 11ms/step - loss: 8.3330e-04 - val_loss: 7.0549e-04
# Epoch 81/100
# 49/49 [==============================] - 1s 11ms/step - loss: 8.1932e-04 - val_loss: 6.2211e-04
# Epoch 82/100
# 49/49 [==============================] - 1s 12ms/step - loss: 8.3804e-04 - val_loss: 6.6443e-04
# Epoch 83/100
# 49/49 [==============================] - 1s 11ms/step - loss: 8.7136e-04 - val_loss: 6.7654e-04
# Epoch 84/100
# 49/49 [==============================] - 1s 11ms/step - loss: 8.3884e-04 - val_loss: 7.9914e-04
# Epoch 85/100
# 49/49 [==============================] - 1s 12ms/step - loss: 8.0763e-04 - val_loss: 7.5880e-04
# Epoch 86/100
# 49/49 [==============================] - 1s 11ms/step - loss: 8.1975e-04 - val_loss: 4.3937e-04
# Epoch 87/100
# 49/49 [==============================] - 1s 11ms/step - loss: 8.3412e-04 - val_loss: 7.1607e-04
# Epoch 88/100
# 49/49 [==============================] - 1s 11ms/step - loss: 7.9182e-04 - val_loss: 6.9406e-04
# Epoch 89/100
# 49/49 [==============================] - 1s 12ms/step - loss: 8.0044e-04 - val_loss: 6.9278e-04
# Epoch 90/100
# 49/49 [==============================] - 1s 12ms/step - loss: 8.3484e-04 - val_loss: 8.4357e-04
# Epoch 91/100
# 49/49 [==============================] - 1s 12ms/step - loss: 7.8869e-04 - val_loss: 8.9910e-04
# Epoch 92/100
# 49/49 [==============================] - 1s 12ms/step - loss: 8.3927e-04 - val_loss: 6.8385e-04
# Epoch 93/100
# 49/49 [==============================] - 1s 11ms/step - loss: 8.0025e-04 - val_loss: 6.7381e-04
# Epoch 94/100
# 49/49 [==============================] - 1s 11ms/step - loss: 7.6897e-04 - val_loss: 9.4294e-04
# Epoch 95/100
# 49/49 [==============================] - 1s 11ms/step - loss: 7.9599e-04 - val_loss: 7.2320e-04
# Epoch 96/100
# 49/49 [==============================] - 1s 11ms/step - loss: 8.2169e-04 - val_loss: 7.5004e-04
# Epoch 97/100
# 49/49 [==============================] - 1s 11ms/step - loss: 8.3345e-04 - val_loss: 6.8314e-04
# Epoch 98/100
# 49/49 [==============================] - 1s 11ms/step - loss: 7.9624e-04 - val_loss: 5.9111e-04
# Epoch 99/100
# 49/49 [==============================] - 1s 11ms/step - loss: 7.9862e-04 - val_loss: 5.5326e-04
# Epoch 100/100
# 49/49 [==============================] - 1s 11ms/step - loss: 7.3999e-04 - val_loss: 6.4522e-04

# %% [markdown]
# ## TRAINING LOSS AND VALIDATION LOSS GRAPH

# %%
# Graph model loss (train loss & val loss)
fig = plt.figure(figsize=(10, 4))
plt.plot(pred.history['loss'], label='train loss')
plt.plot(pred.history['val_loss'], label='val loss')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ## Training Loss & Validation Loss Table

# %%
# Tabel value of training loss & validation loss
learningrate_parameter = learning_rate
train_loss=pred.history['loss'][-1]
validation_loss=pred.history['val_loss'][-1]
learningrate_parameter=pd.DataFrame(data=[[learningrate_parameter, train_loss, validation_loss]],
                                    columns=['Learning Rate', 'Training Loss', 'Validation Loss'])
learningrate_parameter.set_index('Learning Rate')
# Out:
#                Training Loss  Validation Loss
# Learning Rate
# 0.0001               0.00074         0.000645

# %% [markdown]
# ## Implementation Model into Data Test

# %%
# Implementation model into data test
y_pred_test = regressorGRU.predict(x_test)

# Invert normalization min-max
y_pred_invert_norm = scaler.inverse_transform(y_pred_test)

# %% [markdown]
# ## Comparison Data Test with Prediction Results

# %%
# Comparison data test with data prediction
datacompareGRU = pd.DataFrame()
datatest=np.array(dataset['close'][totaldatatrain+totaldataval+lag:])
datapred= y_pred_invert_norm

datacompareGRU['Data Test'] = datatest
datacompareGRU['Prediction Results'] = datapred
datacompareGRU
# Out:
#       Data Test  Prediction Results
# 0      39371.86        39222.902344
# 1      39346.48        39159.695312
# 2      39086.66        39136.207031
# 3      38864.34        38895.503906
# 4      38473.23        38689.238281
# ...         ...                 ...
# 4984   41914.97        40990.902344
# 4985   41659.53        41495.039062
# 4986   42907.32        41262.160156
# 4987   43178.98        42396.097656
# 4988   43312.27        42641.742188
#
# [4989 rows x 2 columns]

# %% [markdown]
# ## Prediction Results Evaluation

# %%
# Calculatre value of Root Mean Square Error 
def rmse(datatest, datapred):
    return np.round(np.sqrt(np.mean((datapred - datatest) ** 2)), 4)
print('Result Root Mean Square Error GRU :',rmse(datatest, datapred))

def mape(datatest, datapred): 
    return np.round(np.mean(np.abs((datatest - datapred) / datatest) * 100), 4)
    
print('Result Mean Absolute Percentage Error GRU : ', mape(datatest, datapred), '%')

print("Model Accuracy:",100-mape(datatest, datapred), '%')
# Out:
# Result Root Mean Square Error GRU : 10583.5176
# Result Mean Absolute Percentage Error GRU :  17.0735 %
# Model Accuracy: 82.9265 %

# %%
# Create graph data test and prediction result
plt.figure(num=None, figsize=(10, 4), dpi=80,facecolor='w', edgecolor='k')
plt.title('Graph Comparison Data Actual and Data Prediction GRU' )
plt.plot(datacompareGRU['Data Test'], color='red',label='Data Test')
plt.plot(datacompareGRU['Prediction Results'], color='blue',label='Prediction Results')
plt.xlabel('Day')
plt.ylabel('Price')
plt.legend()

plt.show()

# %% [markdown]
# # MODELS COMPARISON GRAPH

# %%
# Create graph data test and prediction result
plt.figure(num=None, figsize=(10, 4), dpi=80,facecolor='w', edgecolor='k')
plt.title('Graph Comparison Data Actual and Data Prediction GRU And LSTM' )
plt.plot(datacompareGRU['Data Test'], color='red',label='Data Test')
plt.plot(datacompareLSTM['Prediction Results'], color='blue',label='LSTM')
plt.plot(datacompareGRU['Prediction Results'], color='green',label='GRU')
plt.xlabel('Day')
plt.ylabel('Price')
plt.legend()                                                                                                                                              
plt.show()
